# %% [markdown]
# # Información de Empleados

# %%
import pandas as pd

# %%
import mysql.connector
from mysql.connector import Error

def create_connection(host_name, user_name, user_password):
    connection = None
    try:
        connection = mysql.connector.connect(
            host=host_name,
            user=user_name,
            passwd=user_password
        )
        print("Connection to MySQL DB successful")
    except Error as e:
        print(f"The error '{e}' occurred")

    return connection

# %%
import warnings
warnings.filterwarnings(action = 'ignore')

# %%
host = "relational.fit.cvut.cz"
user = "guest"
pwd = "relational"
connection = create_connection(host_name = host, user_name =user ,user_password = pwd)
# Out:
# Connection to MySQL DB successful

# %%
query = "SHOW TABLES from employee;"
tables = pd.read_sql(query,connection)
tables
# Out:
#   Tables_in_employee
# 0        departments
# 1           dept_emp
# 2       dept_manager
# 3          employees
# 4           salaries
# 5             titles

# %%
query = "select * from employee.dept_emp limit 10;"
employees = pd.read_sql(query,connection)
employees
# Out:
#    emp_no dept_no   from_date     to_date
# 0   10001    d005  1986-06-26  9999-01-01
# 1   10002    d007  1996-08-03  9999-01-01
# 2   10003    d004  1995-12-03  9999-01-01
# 3   10004    d004  1986-12-01  9999-01-01
# 4   10005    d003  1989-09-12  9999-01-01
# 5   10006    d005  1990-08-05  9999-01-01
# 6   10007    d008  1989-02-10  9999-01-01
# 7   10008    d005  1998-03-11  2000-07-31
# 8   10009    d006  1985-02-18  9999-01-01
# 9   10010    d004  1996-11-24  2000-06-26

# %%
query = """ SELECT
                e.first_name,
                e.last_name,
                e.emp_no,
                t.title,
                t.from_date,
                t.to_date,
                s.salary
         FROM employee.employees e  
         LEFT JOIN employee.titles t on e.emp_no = t.emp_no
         LEFT JOIN employee.salaries s on t.emp_no = s.emp_no
         WHERE e.emp_no = 12557
"""
emp_titles = pd.read_sql(query,connection)
emp_titles
# Out:
#    first_name last_name  emp_no            title   from_date     to_date  \
# 0    Stafford    Kopetz   12557  Senior Engineer  1988-03-20  9999-01-01
# 1    Stafford    Kopetz   12557  Senior Engineer  1988-03-20  9999-01-01
# 2    Stafford    Kopetz   12557  Senior Engineer  1988-03-20  9999-01-01
# 3    Stafford    Kopetz   12557  Senior Engineer  1988-03-20  9999-01-01
# 4    Stafford    Kopetz   12557  Senior Engineer  1988-03-20  9999-01-01
# 5    Stafford    Kopetz   12557  Senior Engineer  1988-03-20  9999-01-01
# 6    Stafford    Kopetz   12557  Senior Engineer  1988-03-20  9999-01-01
# 7    Stafford    Kopetz   12557  Senior Engineer  1988-03-20  9999-01-01
# 8    Stafford    Kopetz   12557  Senior Engineer  1988-03-20  9999-01-01
# 9    Stafford    Kopetz   12557  Senior Engineer  1988-03-20  9999-01-01
# 10   Stafford    Kopetz   12557  Senior Engineer  1988-03-20  9999-01-01
# 11   Stafford    Kopetz   12557  Senior Engineer  1988-03-20  9999-01-01
# 12   Stafford    Kopetz   12557  Senior Engineer  1988-03-20  9999-01-01
# 13   Stafford    Kopetz   12557  Senior Engineer  1988-03-20  9999-01-01
# 14   Stafford    Kopetz   12557  Senior Engineer  1988-03-20  9999-01-01
#
#     salary
# 0    41840
# 1    46021
# 2    48699
# 3    51610
# 4    51351
# 5    51660
# 6    52878
# 7    54053
# 8    57950
# 9    58055
# 10   58863
# 11   60447
# 12   60959
# 13   62951
# 14   64554

# %%
query = """ SELECT
                e.first_name,
                e.last_name,
                birth_date,
                e.emp_no,
                t.title,
                s.from_date,
                s.to_date
            FROM employee.employees e
            JOIN employee.titles t ON e.emp_no = t.emp_no
            JOIN employee.salaries s ON e.emp_no = s.emp_no
            WHERE e.emp_no = 12557
            ORDER BY s.from_date DESC limit 1
"""
emp_titles = pd.read_sql(query,connection)
emp_titles
# Out:
#   first_name last_name  birth_date  emp_no            title   from_date  \
# 0   Stafford    Kopetz  1954-01-01   12557  Senior Engineer  2002-03-17
#
#       to_date
# 0  9999-01-01

# %%
query = """ SELECT 
                e.first_name,
                e.last_name,
                e.emp_no,
                t.title,
                t.from_date,
                t.to_date,
                s.salary,
                ROW_NUMBER() OVER(PARTITION BY e.emp_no ORDER BY s.salary DESC) seq
            FROM employee.employees e
            LEFT JOIN employee.titles t on e.emp_no = t.emp_no
            LEFT JOIN employee.salaries s on t.emp_no = s.emp_no
        WHERE seq = 1;
        GROUP BY 1,2,3,4,5,6,7
            
"""
emp_titles = pd.read_sql(query,connection)
emp_titles
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~/opt/anaconda3/envs/data_wrangling/lib/python3.8/site-packages/mysql/connector/connection_cext.py:470, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     469         query = query.encode('utf-8')
# --> 470     self._cmysql.query(query,
#     471                        raw=raw, buffered=buffered,
#     472                        raw_as_string=raw_as_string)
#     473 except MySQLInterfaceError as exc:
#
# MySQLInterfaceError: You have an error in your SQL syntax; check the manual that corresponds to your MariaDB server version for the right syntax to use near 'WHERE seq = 1' at line 14
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# File ~/opt/anaconda3/envs/data_wrangling/lib/python3.8/site-packages/pandas/io/sql.py:2020, in SQLiteDatabase.execute(self, *args, **kwargs)
#    2019 try:
# -> 2020     cur.execute(*args, **kwargs)
#    2021     return cur
#
# File ~/opt/anaconda3/envs/data_wrangling/lib/python3.8/site-packages/mysql/connector/cursor_cext.py:264, in CMySQLCursor.execute(self, operation, params, multi)
#     263 try:
# --> 264     result = self._cnx.cmd_query(stmt, raw=self._raw,
#     265                                  buffered=self._buffered,
#     266                                  raw_as_string=self._raw_as_string)
#     267 except MySQLInterfaceError as exc:
#
# File ~/opt/anaconda3/envs/data_wrangling/lib/python3.8/site-packages/mysql/connector/connection_cext.py:474, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     473 except MySQLInterfaceError as exc:
# --> 474     raise errors.get_mysql_exception(exc.errno, msg=exc.msg,
#     475                                      sqlstate=exc.sqlstate)
#     476 except AttributeError:
#
# ProgrammingError: 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MariaDB server version for the right syntax to use near 'WHERE seq = 1' at line 14
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Input In [56], in <cell line: 17>()
#       1 query = """ SELECT
#       2                 e.first_name,
#       3                 e.last_name,
#    (...)
#      15
#      16 """
# ---> 17 emp_titles = pd.read_sql(query,connection)
#      18 emp_titles
#
# File ~/opt/anaconda3/envs/data_wrangling/lib/python3.8/site-packages/pandas/io/sql.py:566, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     563 pandas_sql = pandasSQL_builder(con)
#     565 if isinstance(pandas_sql, SQLiteDatabase):
# --> 566     return pandas_sql.read_query(
#     567         sql,
#     568         index_col=index_col,
#     569         params=params,
#     570         coerce_float=coerce_float,
#     571         parse_dates=parse_dates,
#     572         chunksize=chunksize,
#     573     )
#     575 try:
#     576     _is_table_name = pandas_sql.has_table(sql)
#
# File ~/opt/anaconda3/envs/data_wrangling/lib/python3.8/site-packages/pandas/io/sql.py:2080, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#    2068 def read_query(
#    2069     self,
#    2070     sql,
#    (...)
#    2076     dtype: DtypeArg | None = None,
#    2077 ):
#    2079     args = _convert_params(sql, params)
# -> 2080     cursor = self.execute(*args)
#    2081     columns = [col_desc[0] for col_desc in cursor.description]
#    2083     if chunksize is not None:
#
# File ~/opt/anaconda3/envs/data_wrangling/lib/python3.8/site-packages/pandas/io/sql.py:2032, in SQLiteDatabase.execute(self, *args, **kwargs)
#    2029     raise ex from inner_exc
#    2031 ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
# -> 2032 raise ex from exc
#
# DatabaseError: Execution failed on sql ' SELECT
#                 e.first_name,
#                 e.last_name,
#                 e.emp_no,
#                 t.title,
#                 t.from_date,
#                 t.to_date,
#                 s.salary,
#                 ROW_NUMBER() OVER(PARTITION BY e.emp_no ORDER BY s.salary DESC) seq
#             FROM employee.employees e
#             LEFT JOIN employee.titles t on e.emp_no = t.emp_no
#             LEFT JOIN employee.salaries s on t.emp_no = s.emp_no
#         GROUP BY 1,2,3,4,5,6,7
#         WHERE seq = 1;
#
# ': 1064 (42000): You have an error in your SQL syntax; check the manual that corresponds to your MariaDB server version for the right syntax to use near 'WHERE seq = 1' at line 14
